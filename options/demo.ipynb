# %%
from pricing_utils import CBOEOptionsData, OptionsPrices
from mzpricer import option_greeks
opts = CBOEOptionsData("/Users/mz/Documents/projects/ztrade/UnderlyingOptionsEODCalcs_2023-08-25_cgi_or_historical.csv", "2023-08-25", ['TSLA'])
df_opts = opts.get_data()
# Out:
# /Users/mz/Documents/projects/ztrade/options/pricing_utils.py:49: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker_symbols, start=start_date, end=as_of_dt)
# [*********************100%***********************]  1 of 1 completed

# %%
prices = OptionsPrices(df_opts)
df = prices.price_options()

# %%
df
# Out:
# shape: (4_238, 17)
# ┌────────┬─────────────────┬────────┬──────┬───┬──────────┬─────────────┬────────────┬─────────────┐
# │ Ticker ┆ ValuationTime   ┆ Spot   ┆ Type ┆ … ┆ Vol30d   ┆ T           ┆ FMV        ┆ %Overvalued │
# │ ---    ┆ ---             ┆ ---    ┆ ---  ┆   ┆ ---      ┆ ---         ┆ ---        ┆ ---         │
# │ str    ┆ datetime[μs,    ┆ f64    ┆ str  ┆   ┆ f64      ┆ f64         ┆ f64        ┆ f64         │
# │        ┆ America/New_Yor ┆        ┆      ┆   ┆          ┆             ┆            ┆             │
# │        ┆ k]              ┆        ┆      ┆   ┆          ┆             ┆            ┆             │
# ╞════════╪═════════════════╪════════╪══════╪═══╪══════════╪═════════════╪════════════╪═════════════╡
# │ TSLA   ┆ 2023-08-23      ┆ 238.33 ┆ C    ┆ … ┆ 0.486163 ┆ 5479.452055 ┆ 230.022572 ┆ -0.052267   │
# │        ┆ 16:00:00 EDT    ┆        ┆      ┆   ┆          ┆             ┆            ┆             │
# ...
